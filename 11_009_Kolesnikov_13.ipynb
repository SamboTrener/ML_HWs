# %%
import keras
import pandas as pd
import matplotlib.pyplot as plt
from keras import utils
import tensorflow as tf
import numpy as np
from keras.optimizers import Adam
from keras.models import Sequential, Model
from keras.layers import concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM, GlobalMaxPooling1D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
df = pd.read_csv('traff.csv', header=None)
df.head()
# Out:
#           0          1
# 0  1/1/2017  22,226.00
# 1  1/2/2017  29,593.00
# 2  1/3/2017  31,726.00
# 3  1/4/2017  32,684.00
# 4  1/5/2017  31,820.00

# %%
df[0] = pd.to_datetime(df[0], format='%m/%d/%Y')
df[1] = list(map(lambda x: float(x.replace(',','')), df[1]))

values = df[1].values
values = values.reshape((-1, 1))

scaler = StandardScaler()
scaled_values = scaler.fit_transform(values)

# %%
train, test = train_test_split(scaled_values, test_size=0.2, shuffle=False)

# %%
len = 3
batch_size = 10

generator = TimeseriesGenerator(train, train, length=len, sampling_rate=1, batch_size=batch_size)
validation_generator = TimeseriesGenerator(test, test, length=len, sampling_rate=1, batch_size=batch_size)

model = Sequential()
model.add(LSTM(32, input_shape=(len, 1), return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(128, return_sequences=True))
model.add(Flatten())
model.add(Dense(64, activation='linear'))
model.add(Dense(128, activation='linear'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit(generator, epochs=60, validation_data=validation_generator, verbose=1)
# Out:
# Epoch 1/60
# 88/88 [==============================] - 9s 29ms/step - loss: 0.3971 - val_loss: 0.3147
# Epoch 2/60
# 88/88 [==============================] - 2s 17ms/step - loss: 0.2013 - val_loss: 0.3142
# Epoch 3/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.1871 - val_loss: 0.2982
# Epoch 4/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.1626 - val_loss: 0.2544
# Epoch 5/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.1876 - val_loss: 0.2827
# Epoch 6/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.1459 - val_loss: 0.2023
# Epoch 7/60
# 88/88 [==============================] - 1s 11ms/step - loss: 0.1110 - val_loss: 0.1474
# Epoch 8/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0765 - val_loss: 0.1049
# Epoch 9/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0737 - val_loss: 0.0984
# Epoch 10/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0738 - val_loss: 0.0951
# Epoch 11/60
# 88/88 [==============================] - 1s 17ms/step - loss: 0.0791 - val_loss: 0.1112
# Epoch 12/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0723 - val_loss: 0.0984
# Epoch 13/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0726 - val_loss: 0.1071
# Epoch 14/60
# 88/88 [==============================] - 1s 11ms/step - loss: 0.0706 - val_loss: 0.1008
# Epoch 15/60
# 88/88 [==============================] - 1s 11ms/step - loss: 0.0852 - val_loss: 0.1024
# Epoch 16/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0746 - val_loss: 0.1250
# Epoch 17/60
# 88/88 [==============================] - 1s 11ms/step - loss: 0.0782 - val_loss: 0.1381
# Epoch 18/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0862 - val_loss: 0.1249
# Epoch 19/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0808 - val_loss: 0.1057
# Epoch 20/60
# 88/88 [==============================] - 2s 17ms/step - loss: 0.0718 - val_loss: 0.1091
# Epoch 21/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0708 - val_loss: 0.1019
# Epoch 22/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0743 - val_loss: 0.1036
# Epoch 23/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0829 - val_loss: 0.1273
# Epoch 24/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0886 - val_loss: 0.1055
# Epoch 25/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0753 - val_loss: 0.0982
# Epoch 26/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0715 - val_loss: 0.1095
# Epoch 27/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0725 - val_loss: 0.1091
# Epoch 28/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0722 - val_loss: 0.0982
# Epoch 29/60
# 88/88 [==============================] - 1s 14ms/step - loss: 0.0736 - val_loss: 0.1129
# Epoch 30/60
# 88/88 [==============================] - 1s 17ms/step - loss: 0.0749 - val_loss: 0.0953
# Epoch 31/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0733 - val_loss: 0.0975
# Epoch 32/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0743 - val_loss: 0.1037
# Epoch 33/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0729 - val_loss: 0.1021
# Epoch 34/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0765 - val_loss: 0.1402
# Epoch 35/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0874 - val_loss: 0.1747
# Epoch 36/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0709 - val_loss: 0.0955
# Epoch 37/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0717 - val_loss: 0.1185
# Epoch 38/60
# 88/88 [==============================] - 1s 15ms/step - loss: 0.0712 - val_loss: 0.1063
# Epoch 39/60
# 88/88 [==============================] - 1s 15ms/step - loss: 0.0816 - val_loss: 0.1583
# Epoch 40/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0999 - val_loss: 0.1142
# Epoch 41/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0774 - val_loss: 0.0994
# Epoch 42/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0766 - val_loss: 0.0970
# Epoch 43/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0708 - val_loss: 0.1014
# Epoch 44/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0735 - val_loss: 0.0963
# Epoch 45/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0710 - val_loss: 0.1000
# Epoch 46/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0732 - val_loss: 0.1217
# Epoch 47/60
# 88/88 [==============================] - 2s 17ms/step - loss: 0.0754 - val_loss: 0.1041
# Epoch 48/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0699 - val_loss: 0.0954
# Epoch 49/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0849 - val_loss: 0.1004
# Epoch 50/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0824 - val_loss: 0.0971
# Epoch 51/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0703 - val_loss: 0.0979
# Epoch 52/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0708 - val_loss: 0.1025
# Epoch 53/60
# 88/88 [==============================] - 1s 16ms/step - loss: 0.0701 - val_loss: 0.1140
# Epoch 54/60
# 88/88 [==============================] - 1s 17ms/step - loss: 0.0708 - val_loss: 0.0990
# Epoch 55/60
# 88/88 [==============================] - 2s 19ms/step - loss: 0.0689 - val_loss: 0.1204
# Epoch 56/60
# 88/88 [==============================] - 2s 18ms/step - loss: 0.0696 - val_loss: 0.1295
# Epoch 57/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0736 - val_loss: 0.0959
# Epoch 58/60
# 88/88 [==============================] - 1s 13ms/step - loss: 0.0720 - val_loss: 0.1165
# Epoch 59/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0768 - val_loss: 0.0940
# Epoch 60/60
# 88/88 [==============================] - 1s 12ms/step - loss: 0.0826 - val_loss: 0.1317

# %%
predicted = model.predict(validation_generator, verbose=True)

plt.figure()
plt.plot(test, label='Настоящие данные')
plt.plot(predicted, label='Предсказанные Данные')
plt.xlabel('Шаг')
plt.ylabel('Значение')
plt.legend()
plt.show()
# Out:
# 22/22 [==============================] - 4s 15ms/step
